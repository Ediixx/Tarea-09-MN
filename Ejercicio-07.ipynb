# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
import numpy as np
from src import eliminacion_gaussiana
from src import eliminacion_gaussiana_punto_flotante
from src import eliminacion_gaussiana_pivoteo
from src import Gauss_Jordan_punto_flotante

# %% [markdown]
# 7. Repita el ejercicio 4 con el método Gauss-Jordan

# %% [markdown]
# 4. Use el algoritmo de Gauss-Jordan y la aritmética computacional de precisión de 32 bits para resolver los
# siguientes sistemas lineales.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Matriz_a = np.array ([[1/4,1/5,1/6,9] , [1/3,1/4,1/5,8] , [1/2,1,2,8]],dtype = np.float32)

Gauss_Jordan_punto_flotante(Matriz_a)
# Out:
# Paso 1: Normalizar fila 1 (hacer pivote igual a 1):
# [[ 1.          0.80000001  0.66666669 36.        ]
#  [ 0.33333334  0.25        0.2         8.        ]
#  [ 0.5         1.          2.          8.        ]]
# --------------------------------------------------
# Paso 1.2: Hacer cero el elemento en la posición (2, 1):
# [[ 1.00000000e+00  8.00000012e-01  6.66666687e-01  3.60000000e+01]
#  [ 0.00000000e+00 -1.66666786e-02 -2.22222325e-02 -4.00000036e+00]
#  [ 5.00000000e-01  1.00000000e+00  2.00000000e+00  8.00000000e+00]]
# --------------------------------------------------
# Paso 1.3: Hacer cero el elemento en la posición (3, 1):
# [[ 1.00000000e+00  8.00000012e-01  6.66666687e-01  3.60000000e+01]
#  [ 0.00000000e+00 -1.66666786e-02 -2.22222325e-02 -4.00000036e+00]
#  [ 0.00000000e+00  5.99999994e-01  1.66666666e+00 -1.00000000e+01]]
# --------------------------------------------------
# Paso 2: Normalizar fila 2 (hacer pivote igual a 1):
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Matriz_b = np.array ([[3.333,15920,-10.333,15913] , [2.222,16.71,9.612,28.544] , [1.5611,5.1791,1.6852,8.4254]],dtype = np.float32)

Gauss_Jordan_punto_flotante(Matriz_b)
# Out:
# Paso 1: Normalizar fila 1 (hacer pivote igual a 1):
# [[ 1.00000000e+00  4.77647773e+03 -3.10021013e+00  4.77437752e+03]
#  [ 2.22199988e+00  1.67099991e+01  9.61200047e+00  2.85440006e+01]
#  [ 1.56110001e+00  5.17910004e+00  1.68519998e+00  8.42539978e+00]]
# --------------------------------------------------
# Paso 1.2: Hacer cero el elemento en la posición (2, 1):
# [[ 1.00000000e+00  4.77647773e+03 -3.10021013e+00  4.77437752e+03]
#  [ 0.00000000e+00 -1.05966230e+04  1.65006670e+01 -1.05801223e+04]
#  [ 1.56110001e+00  5.17910004e+00  1.68519998e+00  8.42539978e+00]]
# --------------------------------------------------
# Paso 1.3: Hacer cero el elemento en la posición (3, 1):
# [[ 1.00000000e+00  4.77647773e+03 -3.10021013e+00  4.77437752e+03]
#  [ 0.00000000e+00 -1.05966230e+04  1.65006670e+01 -1.05801223e+04]
#  [ 0.00000000e+00 -7.45138031e+03  6.52493802e+00 -7.44485537e+03]]
# --------------------------------------------------
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Matriz_c = np.array ([[1,1/2,1/3,1/4,1/6] , [1/2,1/3,1/4,1/5,1/7] , [1/3,1/4,1/5,1/6,1/8],[1/4,1/5,1/6,1/7,1/9]],dtype = np.float32)

Gauss_Jordan_punto_flotante(Matriz_c)
# Out:
# Paso 1: Normalizar fila 1 (hacer pivote igual a 1):
# [[1.         0.5        0.33333334 0.25       0.16666667]
#  [0.5        0.33333334 0.25       0.2        0.14285715]
#  [0.33333334 0.25       0.2        0.16666667 0.125     ]
#  [0.25       0.2        0.16666667 0.14285715 0.11111111]]
# --------------------------------------------------
# Paso 1.2: Hacer cero el elemento en la posición (2, 1):
# [[1.         0.5        0.33333334 0.25       0.16666667]
#  [0.         0.08333334 0.08333333 0.075      0.05952381]
#  [0.33333334 0.25       0.2        0.16666667 0.125     ]
#  [0.25       0.2        0.16666667 0.14285715 0.11111111]]
# --------------------------------------------------
# Paso 1.3: Hacer cero el elemento en la posición (3, 1):
# [[1.         0.5        0.33333334 0.25       0.16666667]
#  [0.         0.08333334 0.08333333 0.075      0.05952381]
#  [0.         0.08333333 0.08888889 0.08333334 0.06944444]
#  [0.25       0.2        0.16666667 0.14285715 0.11111111]]
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Matriz_d = np.array ([[2,1,-1,1,-3,7] , [1,0,2,-1,1,2] , [0,-2,-1,1,-1,-5],[3,1,-4,0,5,6],[1,-1,-1,-1,1,-3]],dtype = np.float32)

Gauss_Jordan_punto_flotante(Matriz_d)
# Out:
# Paso 1: Normalizar fila 1 (hacer pivote igual a 1):
# [[ 1.   0.5 -0.5  0.5 -1.5  3.5]
#  [ 1.   0.   2.  -1.   1.   2. ]
#  [ 0.  -2.  -1.   1.  -1.  -5. ]
#  [ 3.   1.  -4.   0.   5.   6. ]
#  [ 1.  -1.  -1.  -1.   1.  -3. ]]
# --------------------------------------------------
# Paso 1.2: Hacer cero el elemento en la posición (2, 1):
# [[ 1.   0.5 -0.5  0.5 -1.5  3.5]
#  [ 0.  -0.5  2.5 -1.5  2.5 -1.5]
#  [ 0.  -2.  -1.   1.  -1.  -5. ]
#  [ 3.   1.  -4.   0.   5.   6. ]
#  [ 1.  -1.  -1.  -1.   1.  -3. ]]
# --------------------------------------------------
# Paso 1.3: Hacer cero el elemento en la posición (3, 1):
# [[ 1.   0.5 -0.5  0.5 -1.5  3.5]
#  [ 0.  -0.5  2.5 -1.5  2.5 -1.5]
#  [ 0.  -2.  -1.   1.  -1.  -5. ]
#  [ 3.   1.  -4.   0.   5.   6. ]
#  [ 1.  -1.  -1.  -1.   1.  -3. ]]
# --------------------------------------------------
# Paso 1.4: Hacer cero el elemento en la posición (4, 1):
# [[ 1.   0.5 -0.5  0.5 -1.5  3.5]
#  [ 0.  -0.5  2.5 -1.5  2.5 -1.5]
# ...
