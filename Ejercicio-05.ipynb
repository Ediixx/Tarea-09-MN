# %%
# %load_ext autoreload

# %%
# %autoreload 2
import numpy as np
from sympy import symbols, Eq, solve, Matrix
from src import eliminacion_gaussiana
from src import eliminacion_gaussiana_punto_flotante
from src import eliminacion_gaussiana_pivoteo
from src import analizar_sistema

# %% [markdown]
# 5. Dado el sistema lineal:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
alpha = symbols('alpha')
Matriz_a = [[1, -1, alpha, -2],[-1, 2, -alpha, 3],[alpha, 1, 1, 2]]

analizar_sistema(Matriz_a)
# Out:
# {'No existe solución en: ': [-1, 1],
#  'Soluciones infinitas en: ': [-1],
#  'Solución Única en: ': None}
