# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
import numpy as np
from src import eliminacion_gaussiana
from src import eliminacion_gaussiana_punto_flotante
from src import eliminacion_gaussiana_pivoteo

# %% [markdown]
# 4. Use el algoritmo de eliminación gaussiana y la aritmética computacional de precisión de 32 bits para resolver los
# siguientes sistemas lineales.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Matriz_a = np.array ([[1/4,1/5,1/6,9] , [1/3,1/4,1/5,8] , [1/2,1,2,8]],dtype = np.float32)

eliminacion_gaussiana_punto_flotante(Matriz_a)
# Out:
# array([-227.07666,  476.92264, -177.69217], dtype=float32)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Matriz_b = np.array ([[3.333,15920,-10.333,15913] , [2.222,16.71,9.612,28.544] , [1.5611,5.1791,1.6852,8.4254]],dtype = np.float32)

eliminacion_gaussiana_punto_flotante(Matriz_b)
# Out:
# Intercambiando filas 0 y 2
# array([0.9999997, 1.0000001, 0.9999998], dtype=float32)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Matriz_c = np.array ([[1,1/2,1/3,1/4,1/6] , [1/2,1/3,1/4,1/5,1/7] , [1/3,1/4,1/5,1/6,1/8],[1/4,1/5,1/6,1/7,1/9]],dtype = np.float32)

eliminacion_gaussiana_punto_flotante(Matriz_c)
# Out:
# Intercambiando filas 0 y 3
# Intercambiando filas 1 y 2
# array([-0.03174075,  0.5951853 , -2.3808312 ,  2.7777011 ], dtype=float32)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Matriz_d = np.array ([[2,1,-1,1,-3,7] , [1,0,2,-1,1,2] , [0,-2,-1,1,-1,-5],[3,1,-4,0,5,6],[1,-1,-1,-1,1,-3]],dtype = np.float32)

eliminacion_gaussiana_punto_flotante(Matriz_d)
# Out:
# Intercambiando filas 0 y 1
# Intercambiando filas 2 y 3
# Intercambiando filas 3 y 4
# array([1.8830411 , 2.807017  , 0.73099416, 1.4385967 , 0.09356727],
#       dtype=float32)
